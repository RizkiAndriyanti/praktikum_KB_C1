# %% [markdown]
# ## IMPORT LIBRARY

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ## MEMBACA FILE DATASET

# %%
df = pd.read_csv('Library_Usage.csv')
df
# Out:
#       Patron Type Code Patron Type Definition  Total Checkouts  \
# 0                    3                 SENIOR               28
# 1                    0                  ADULT               21
# 2                    0                  ADULT              275
# 3                    0                  ADULT               73
# 4                    0                  ADULT              182
# ...                ...                    ...              ...
# 2332                 0                  ADULT                3
# 2333                 0                  ADULT              193
# 2334                 0                  ADULT                0
# 2335                 0                  ADULT                0
# 2336                 0                  ADULT                5
#
#       Total Renewals       Age Range Home Library Code  \
# 0                 13  65 to 74 years                 X
# 1                 10  55 to 59 years                 X
# ...

# %% [markdown]
# ## KUNCI DATAFRAME

# %%
df.keys()
# Out:
# Index(['Patron Type Code', 'Patron Type Definition', 'Total Checkouts',
#        'Total Renewals', 'Age Range', 'Home Library Code',
#        'Home Library Definition', 'Circulation Active Month',
#        'Circulation Active Year', 'Notice Preference Code',
#        'Notice Preference Definition', 'Provided Email Address',
#        'Year Patron Registered', 'Outside of County', 'Supervisor District'],
#       dtype='object')

# %% [markdown]
# ## INFO DARI DATASET

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2337 entries, 0 to 2336
# Data columns (total 15 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Patron Type Code              2337 non-null   int64
#  1   Patron Type Definition        2337 non-null   object
#  2   Total Checkouts               2337 non-null   int64
#  3   Total Renewals                2337 non-null   int64
#  4   Age Range                     2337 non-null   object
#  5   Home Library Code             2337 non-null   object
#  6   Home Library Definition       2337 non-null   object
#  7   Circulation Active Month      2337 non-null   object
#  8   Circulation Active Year       2337 non-null   object
#  9   Notice Preference Code        2337 non-null   object
#  10  Notice Preference Definition  2337 non-null   object
#  11  Provided Email Address        2337 non-null   bool
# ...

# %% [markdown]
# ## DESKRIPSI DARI DATASET

# %%
df.describe()
# Out:
#        Patron Type Code  Total Checkouts  Total Renewals  \
# count       2337.000000      2337.000000     2337.000000
# mean           1.082585       263.771930      123.648695
# std            3.863303       666.442601      343.747368
# min            0.000000         0.000000        0.000000
# 25%            0.000000         5.000000        0.000000
# 50%            0.000000        43.000000       11.000000
# 75%            0.000000       230.000000       84.000000
# max          100.000000     12740.000000     4793.000000
#
#        Year Patron Registered  Supervisor District
# count             2337.000000          1800.000000
# mean              2007.720582             6.327778
# std                  5.028452             3.059227
# min               2003.000000             1.000000
# 25%               2003.000000             4.000000
# 50%               2006.000000             7.000000
# 75%               2013.000000             9.000000
# ...

# %% [markdown]
# ## KORELASI DATA

# %%
df.corr()
# Out:
# C:\Users\MSi-MODERN\AppData\Local\Temp\ipykernel_11964\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                         Patron Type Code  Total Checkouts  Total Renewals  \
# Patron Type Code                1.000000        -0.011419       -0.013837
# Total Checkouts                -0.011419         1.000000        0.616093
# Total Renewals                 -0.013837         0.616093        1.000000
# Provided Email Address         -0.035467        -0.014240        0.052176
# Year Patron Registered          0.112008        -0.314362       -0.290555
# Outside of County               0.122874        -0.066926       -0.044699
# Supervisor District             0.005343        -0.071754       -0.070915
#
#                         Provided Email Address  Year Patron Registered  \
# ...

# %% [markdown]
# ## GARFIK BOXFLOT

# %%
plt.boxplot(df[['Patron Type Code','Total Checkouts']], labels=['patron','total'])
plt.show()

# %% [markdown]
# ## GRAFIK HEATMAP

# %%
sns.heatmap(data=df.corr(), cmap = 'Blues')
plt.show()
# Out:
# C:\Users\MSi-MODERN\AppData\Local\Temp\ipykernel_11964\3639900268.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data=df.corr(), cmap = 'Blues')

# %% [markdown]
# ## GRAFIK BATANG
#
# jadi pada grafik batang pada atribut supervisor district memiliki nilai paling tinggi yaitu lebih dari 200.

# %%
df['Supervisor District'].value_counts().plot.bar()
plt.show()

# %% [markdown]
# ## GRAFIK HSTROGRAM
#
# Pada grafik histogram, pada atribut supervisor district memiliki nilai paling tinggi yaitu lebih dari 200.

# %%
plt.figure(figsize=(10,5))
plt.hist(df['Supervisor District'],label='supervisor',color='skyblue')
plt.legend()
plt.xticks(rotation =90)
plt.show()

# %% [markdown]
# ## GRAFIK PIE
#
# pada grafik pie, menjelaskan hasil sikulasi pada setiap bulan pada data set perpustakaan.

# %%
plt.figure(figsize=(10,5))
plt.pie(df['Circulation Active Month'].value_counts(),labels=['Januari','Februari','Maret','April','Mei','Juni','Juli','Agustus','September','Oktober','November','Desember','None'], startangle=90, autopct='%.1f%%')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# ## GRAFIK PLOT DAN GARIS

# %%
plt.figure(figsize=(10,5))
plt.title('Grafik Plot dan Garis')
plt.plot(df['Circulation Active Year'], df['Circulation Active Month'], linestyle ='--',color = 'skyblue')
plt.xlabel('nilai x')
plt.ylabel('nilai y')
plt.legend()
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## SCATTER PLOT

# %%
plt.figure(figsize=(10,5))
plt.title('Scatter Plot')
plt.scatter(df['Circulation Active Year'], df['Circulation Active Month'], linestyle ='--',color = 'skyblue')
plt.xlabel('nilai x')
plt.ylabel('nilai y')
plt.legend()
plt.xticks(rotation=90)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
